# %%
# %pip install --upgrade llama-index        # core
# %pip install --upgrade llama-index-llms-google-genai  # Google / Gemini LLM integration
# %pip install --upgrade llama-index-embeddings-google-genai  # embeddings via Google GenAI
# %pip install --upgrade google-generativeai  # underlying Google SDK
# Out:
# Requirement already satisfied: llama-index in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.14.8)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.14.8)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.6.10)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.5.5)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: nltk>3.8.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index) (3.9.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (3.12.13)
# Requirement already satisfied: aiosqlite in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2025.10.0)
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.11.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (3.5)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.3.3)
# Requirement already satisfied: pillow>=9.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (10.4.0)
# Requirement already satisfied: platformdirs in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (4.3.7)
# Requirement already satisfied: pydantic>=2.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.11.9)
# Requirement already satisfied: pyyaml>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (4.14.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.20.1)
# Requirement already satisfied: griffe in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.15.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (2.8.1)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.13.4)
# Requirement already satisfied: defusedxml>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.4.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.7)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.11.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (3.10)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.8->llama-index) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.4.1)
# Requirement already satisfied: llama-cloud==0.1.35 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: llama-parse>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click<9,>=8.1.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.3.1)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.1)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index) (2025.9.18)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.8->llama-index) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-google-genai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.7.4)
# Requirement already satisfied: google-genai<2,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-llms-google-genai) (1.52.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-llms-google-genai) (0.14.8)
# Requirement already satisfied: pillow>=10.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-llms-google-genai) (10.4.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.11.9)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.12.13)
# Requirement already satisfied: aiosqlite in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2025.10.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.11.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.9.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.3.3)
# Requirement already satisfied: platformdirs in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.3.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.0.2)
# Requirement already satisfied: setuptools>=80.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.0.43)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.20.1)
# Requirement already satisfied: griffe in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.15.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.6.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (8.3.1)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2025.9.18)
# Requirement already satisfied: greenlet>=1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-embeddings-google-genai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.3.1)
# Requirement already satisfied: google-genai<2,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-embeddings-google-genai) (1.52.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-embeddings-google-genai) (0.14.8)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2.11.9)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.12.13)
# Requirement already satisfied: aiosqlite in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2025.10.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.11.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.9.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.3.3)
# Requirement already satisfied: pillow>=9.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (10.4.0)
# Requirement already satisfied: platformdirs in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (4.3.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (6.0.2)
# Requirement already satisfied: setuptools>=80.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.0.43)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.20.1)
# Requirement already satisfied: griffe in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.15.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-embeddings-google-genai) (0.6.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (8.3.1)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2025.9.18)
# Requirement already satisfied: greenlet>=1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-generativeai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (2.182.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (4.25.8)
# Requirement already satisfied: pydantic in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (2.11.9)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-generativeai) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.75.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic->google-generativeai) (0.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pinecone import Pinecone
from llama_index.core import (
 Settings,
 VectorStoreIndex,
 SimpleDirectoryReader,
 KeywordTableIndex,)
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.selectors import LLMSingleSelector
from llama_index.core.query_engine import RouterQueryEngine,SubQuestionQueryEngine
from llama_index.core.question_gen import LLMQuestionGenerator
from llama_index.core.query_engine import SubQuestionQueryEngine

# %%
# ============================ 3) Query layer (Rerank + Dedup + Compress + Budget) ============================
def answer_with_controls(
    question: str,
    base_k: int = 20,
    rerank_top_n: int = 6,
    dedup_cutoff: float = 0.90,
    char_budget: int = 3500
):
    """
    Reranking: cross-encoder reorders by relevance
    Deduplication: drops near-duplicate nodes
    Compression: LLM extracts query-focused snippets
    Context budgeting: packs <= char_budget into the prompt
    """

    # --- 3.1 RETRIEVE (semantic) ---
    retriever = index.as_retriever(similarity_top_k=base_k)
    nodes = retriever.retrieve(question)  # 1 embedding call for Pinecone

    # --- 3.2 RERANK (cross-encoder) ---
    reranker = SentenceTransformerRerank(
        model="cross-encoder/ms-marco-MiniLM-L-6-v2",  # fast + accurate
        top_n=rerank_top_n,
    )
    nodes = reranker.postprocess_nodes(nodes, query_str=question)

    # --- 3.3 DEDUPLICATION (drop near-duplicates) ---
    dedup = SimilarityPostprocessor(similarity_cutoff=dedup_cutoff)
    nodes = dedup.postprocess_nodes(nodes)

    # --- 3.4 COMPRESSION (LLM extracts key parts) ---
    compressor = LLMChainExtractor.from_defaults(llm=Settings.llm)
    nodes = compressor.postprocess_nodes(nodes, query_str=question)

    # --- 3.5 CONTEXT BUDGETING (limit prompt size) ---
    context_parts = []
    total = 0

    for n in nodes:
        t = n.node.get_content()

        # If adding this chunk exceeds the total budget → trim it
        if total + len(t) > char_budget:
            t = t[: max(0, char_budget - total)]

        # Only add non-empty text
        if t:
            context_parts.append(t)
            total += len(t)

        # Stop if we reached the limit
        if total >= char_budget:
            break

    context = "\n\n---\n\n".join(context_parts)

    # --- 3.6 FINAL SYNTHESIS (1 LLM call) ---
    prompt = f"""
Answer the QUESTION using only the CONTEXT. 
Be concise and cite sections briefly if helpful.

CONTEXT:
{context}

QUESTION:
{question}
"""

    return Settings.llm.complete(prompt).text
