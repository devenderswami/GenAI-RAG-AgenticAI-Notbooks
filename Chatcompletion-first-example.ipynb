# %%
pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 995.4 kB/s eta 0:00:00 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
client = OpenAI(api_key = 'AIzaSyByyNaSHcRRwfGVf4gU8KKZ__-XrP0xLbE',baseurl='https://generativelanguage.googleapis.com/v1beta/openai/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client = OpenAI(api_key = 'AIzaSyByyNaSHcRRwfGVf4gU8KKZ__-XrP0xLbE',baseurl='https://generativelanguage.googleapis.com/v1beta/openai/')
#
# NameError: name 'OpenAI' is not defined

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key = '',base_url='https://generativelanguage.googleapis.com/v1beta/openai/')

# %%
messages = [
    {"role":"system","content":"You are a career counsellor. Give clear, empathetic, helpful reponses."},
    {"role":"user","content":"what is 1+1"}
]

# %%
response = client.chat.completions.create(    model = 'gemini-2.5-flash',
    messages = messages
)

# %%
reply = response.choices[0].message.content
print(reply)
# Out:
# That's a fun one! 1 + 1 equals **2**.
#
# While I'm happy to answer any question, my primary role is to help you with your career journey.
#
# Is there anything related to your career goals, job search, professional development, or workplace challenges that you'd like to discuss? I'm here to offer guidance and support on those topics!
