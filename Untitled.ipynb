# %%
# !pip install -q "numpy<2.0" --force-reinstall
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.1 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.4 which is incompatible.

# %%
# !pip install -q langchain==0.3.13 langchain-google-genai==2.0.5 langchain-community==0.3.13 faiss-cpu==1.8.0
# Out:
# ERROR: Could not find a version that satisfies the requirement faiss-cpu==1.8.0 (from versions: 1.9.0.post1, 1.10.0, 1.11.0, 1.11.0.post1, 1.12.0, 1.13.0, 1.13.1)
# ERROR: No matching distribution found for faiss-cpu==1.8.0
